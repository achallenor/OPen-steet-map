# %%
osm_file = open("OSM Chester and Tarporley.xml", "r")

# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

#OSMFILE = "example.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "Ave" :"Avenue",
            "St.": "Street",
            "Rd." : "Road",
            "N.":"North",
            "E." : "East",
            "S." : "South",
            "W." : "West"
        
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    #osm_file = open(osm_file, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    dict_map = sorted(mapping.keys(), key=len,)
    for key in dict_map:

            if name.find(key):          
                name = name.replace(key,mapping[key])
                return name
    # YOUR CODE HERE

    return name


def test():
    st_types = audit(osm_file)
    #assert len(st_types) == 3
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print (name, "=>", better_name)
            if name == "West Lexington St.":
                assert better_name == "West Lexington Street"
            if name == "Baldwin Rd.":
                assert better_name == "Baldwin Road"


if __name__ == '__main__':
    test()
# Out:
# {'Arcade': {'The Arcade'},
#  'Bank': {'Beauty Bank',
#           'Church Bank',
#           'Crown Bank',
#           'Mere Bank',
#           'Moss Bank',
#           'Newton Bank',
#           'Quarry Bank',
#           'School Bank'},
#  'Beechfield': {'Beechfield'},
#  'Beechfields': {'Beechfields'},
#  'Boothsdale': {'Boothsdale'},
#  'Bridge': {'Hayhurst Bridge', 'Town Bridge', 'Wharton Bridge'},
#  'By-pass': {'Winsford By-pass'},
#  'Bypass': {'Chester Road Bypass'},
#  'Centre': {'Gadbrook Business Centre'},
#  'Close': {'Acorn Close',
#            'Arkwright Close',
#            'Austin Close',
#            'Barber Close',
#            'Bollin Close',
#            'Bramhall Close',
#            'Brockwell Close',
#            'Bude Close',
#            'Capesthorne Close',
#            'Carver Close',
#            'Catalan Close',
#            'Cavendish Close',
#            'Denbigh Close',
#            'Denton Close',
#            'Doulton Close',
#            'Dutch Close',
#            'Ecton Close',
#            'Everdon Close',
#            'Farndon Close',
#            'Fernbank Close',
#            'Firth Close',
#            'Firthfields Close',
#            'Firtree Close',
#            'Foresters Close',
#            'Furness Close',
#            'Gorse Close',
#            'Hamletts Close',
#            'Harvest Close',
#            'Helmdon Close',
#            'Hilton Close',
#            'Island Close',
#            'Kintore Close',
#            'Launceston Close',
#            'Lawrence Close',
#            'Linnet Close',
#            'Ludlow Close',
#            'Maidwell Close',
#            'Manor Close',
#            'Mereheath Close',
#            'Merlin Close',
#            'Noden Close',
#            'Nun House Close',
#            'Nunsmere Close',
#            'Orton Close',
#            'Pinetree Close',
#            'Quantock Close',
#            'Registry Close',
#            'Rose Bank Close',
#            'Spey Close',
#            'Spinney Close',
#            'St Wilfreds Close',
#            'Stanneybrook Close',
#            'Stirling Close',
#            'Tatton Close',
#            'Thirlmere Close',
#            'Thornton Close',
#            'Trent Close',
#            'Turner Close',
#            'Upton Close',
#            'Verdin Close',
#            'Westbury Close',
#            'Whiston Close',
#            'Woodham Close',
#            'Woodlark Close',
#            'Woods Close'},
#  'Cloverfields': {'Cloverfields'},
#  'Cobbles': {'The Cobbles'},
#  'Coppice': {'The Coppice'},
#  'Cottages': {'Crofton Cottages',
#               'New Pale Cottages',
#               'Rookery Cottages',
#               'Waterloo Cottages'},
#  'Crescent': {'Britten Crescent',
#               'Clyde Crescent',
#               'Didsbury Crescent',
#               'Eaton Crescent',
#               'Newall Crescent',
#               'Princess Crescent',
#               'Sandown Crescent',
#               'School Crescent',
#               'The Crescent'},
#  'Crewe': {'Market Street, Crewe'},
#  'Croft': {'Dillors Croft'},
#  'Crossway': {'Saxon Crossway'},
#  'Dingle': {'The Dingle'},
#  'Drumber': {'The Drumber'},
#  'Estate': {'Ion Path, Winsford Industrial Estate',
#             'Road 1, Winsford Industrial Estate',
#             'Road 3, Winsford Industrial Estate'},
#  'Estates': {'The Square Latham Estates'},
#  'Farm': {'Barrow Hall Farm'},
#  'Fernway': {'Fernway'},
#  'Fieldfare': {'Fieldfare'},
#  'Fields': {'Saint Chads Fields', 'Trinity Fields', 'Firth Fields'},
#  'Five': {'Road Five'},
#  'Flaxmere': {'Flaxmere'},
#  'Four': {'Road Four'},
#  'Gardens': {'Holst Gardens',
#              'Rookery Gardens',
#              'Royal Gardens',
#              'Wallcroft Gardens',
#              'Wharton Gardens',
#              'Whittington Gardens'},
#  'Gove': {'Byrd Gove'},
#  'Grange': {'Weaver Grange', 'Ashley Grange'},
#  'Green': {'Long Green', 'Ways Green', 'Bostock Green'},
#  'Greenfields': {'Greenfields'},
#  'Grove': {'Alderton Grove',
#            'Beckenham Grove',
#            'Bentley Grove',
#            'Burland Grove',
#            'Cedar Grove',
#            'Curzon Grove',
#            'Elm Grove',
#            'Fulton Grove',
#            'Hartwell Grove',
#            'Hawthorne Grove',
#            'Lime Grove',
#            'Maple Grove',
#            'Meadow Grove',
#            'Pine Grove',
#            'Weaver Grove',
#            'Westminster Grove',
#            'Wildings Grove'},
#  'Grovemount': {'Grovemount'},
#  'Hall': {'The Walled garden, Bostock Hall', 'Bostock Hall', 'Wharton Hall'},
#  'Haslington': {'Crewe Road, Haslington'},
#  'Heath': {'Hollowmore Heath'},
#  'Hightown': {'Hightown'},
#  'Hill': {'Burrows Hill',
#           'Cinder Hill',
#           'Cooks Hill',
#           'Maddocks Hill',
#           'Stocks Hill',
#           'The Hill',
#           'Winnington Hill'},
#  'Hollies': {'The Hollies'},
#  'Hollow': {'Hambletts Hollow', 'Pytchleys Hollow'},
#  'Kingsway': {'Kingsway'},
#  'Lea': {'Ardern Lea'},
#  'Linwood': {'Linwood'},
#  'Longlooms': {'Longlooms'},
#  'Maples': {'The Maples'},
#  'Meadow': {'Darkie Meadow', 'Rean Meadow'},
#  'Meadowbank': {'School Road, Meadowbank'},
#  'Mews': {'Royal Mews', 'The Mews'},
#  'Oaks': {'The Oaks'},
#  'One': {'Pineapple Park, Road One', 'Road One'},
#  'Parade': {'Queens Parade'},
#  'Park': {'Gadbrook Park', 'Heyes Park', 'Manor Park'},
#  'Pavilions': {'The Pavilions'},
#  'Poppies': {'The Poppies'},
#  'Queensway': {'Queensway'},
#  'Ring': {'Bull Ring'},
#  'Rise': {'Bedford Rise',
#           'Berkeley Rise',
#           'Bowland Rise',
#           'Hunters Rise',
#           'Longmynd Rise',
#           'Orchard Rise',
#           'Rookery Rise',
#           'Scholar Rise'},
#  'Road]': {'High Street [Newcastle Road]'},
#  'Rosemount': {'Rosemount'},
#  'Row': {'Abbotts Row'},
#  'Slack': {'Guests Slack'},
#  'Terrace': {'Dierdens Terrace', 'Saint James Terrace', 'Swan Terrace'},
#  'Two': {'Road Two'},
#  'View': {'Lakeside View', 'Crowton View', 'Hawkins View', 'Eaton View'},
#  'Walk': {'Alt Walk',
#           'Avon Walk',
#           'Canal Walk',
#           'Castlemead Walk',
#           'Church Walk',
#           'Dart Walk',
#           'Dingle Walk',
#           'Finsbury Walk',
#           'Gowy Walk',
#           'Kingsley Walk',
#           'Leyland Walk',
#           'Severn Walk',
#           'Stephenson Walk',
#           'Tamar Walk',
#           'Witton Walk'},
#  'Way': {'Abbotts Way',
#          'Aldford Way',
#          'Barnside Way',
#          'Basford Way',
#          'Bessemer Way',
#          'Brecon Way',
#          'Browning Way',
#          'Byley Way',
#          'Caldy Way',
#          'Calveley Way',
#          'Cambrian Way',
#          'Chester Way',
#          'Chiltern Way',
#          'Civic Way',
#          'Cleveland Way',
#          'Coleridge Way',
#          'Cotswold Way',
#          'Dee Way',
#          'Delaisy Way',
#          'Dukes Way',
#          'Dunwoody Way',
#          'Grampian Way',
#          'Grand Junction Way',
#          'Groves Way',
#          'Hambleton Way',
#          'Jubilee Way',
#          'Lawton Way',
#          'Macon Way',
#          'Malvern Way',
#          'Market Way',
#          'Montgomery Way',
#          'Pembroke Way',
#          'Pochin Way',
#          'Regents Way',
#          'Rennine Way',
#          'Sanbec Way',
#          'School Way',
#          'Snowdonia Way',
#          "St Michael's Way",
#          'Tarvin Way',
#          'Thames Way',
#          'Thrush Way',
#          'Vauxhall Way'},
#  'Wellfield': {'Wellfield'},
#  'West': {'Woodford Lane West'},
#  'Wheelock.': {'Game Street, Wheelock.'},
#  'Yard': {'Old Stack Yard'},
#  'green': {'Mondrem green'},
#  'lane': {'Church lane', 'Irons lane'}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-07f8a8fdc582> in <module>
#      89
#      90 if __name__ == '__main__':
# ---> 91     test()
#
# <ipython-input-2-07f8a8fdc582> in test()
#      78     pprint.pprint(dict(st_types))
#      79
# ---> 80     for st_type, ways in st_types.iteritems():
#      81         for name in ways:
#      82             better_name = update_name(name, mapping)
#
# AttributeError: 'collections.defaultdict' object has no attribute 'iteritems'
